# %% [markdown]
# <a href="https://colab.research.google.com/github/archiegoodman2/neural_net/blob/main/nn_feedforward_UNSW_NB15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import pandas as pd
import tensorflow as tf
from tensorflow import keras

#if using colabs - will need to first mount your drive

data_folder = '/content/drive/MyDrive/Colab_Notebooks/Data'  # Replace with your path if needed

# Import the two CSV files
test_set = pd.read_parquet(data_folder + '/UNSW_NB15_testing-set.parquet')
train_set = pd.read_parquet(data_folder + '/UNSW_NB15_training-set.parquet')

# Now you can work with df1 and df2 (your DataFrames)
test_set.head(10)
train_set.head(10)
# Out:
#         dur proto service state  spkts  dpkts  sbytes  dbytes       rate  \
# 0  0.121478   tcp       -   FIN      6      4     258     172  74.087486
# 1  0.649902   tcp       -   FIN     14     38     734   42014  78.473373
# 2  1.623129   tcp       -   FIN      8     16     364   13186  14.170161
# 3  1.681642   tcp     ftp   FIN     12     12     628     770  13.677108
# 4  0.449454   tcp       -   FIN     10      6     534     268  33.373825
# 5  0.380537   tcp       -   FIN     10      6     534     268  39.417980
# 6  0.637109   tcp       -   FIN     10      8     534     354  26.683033
# 7  0.521584   tcp       -   FIN     10      8     534     354  32.593025
# 8  0.542905   tcp       -   FIN     10      8     534     354  31.313030
# 9  0.258687   tcp       -   FIN     10      6     534     268  57.985134
#
#           sload  ...  trans_depth  response_body_len  ct_src_dport_ltm  \
# 0  14158.942383  ...            0                  0                 1
# ...

# %%
#print out number of classifications
print(f"Number of categories in 'label' category: {len(train_set['label'].unique())}")

#print out labels
print(f"Labels: {train_set['label'].unique()}")
# Out:
# Number of categories in 'label' category: 2
# Labels: [0 1]
