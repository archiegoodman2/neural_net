# %% [markdown]
# <a href="https://colab.research.google.com/github/archiegoodman2/neural_net/blob/feedforward/nn_intrusion_detection_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
